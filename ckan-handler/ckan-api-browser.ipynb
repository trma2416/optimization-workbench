# %% [markdown]
# # CKAN Database

# %% [markdown]
# The CKAN Database is a commonly used and world renowned database where governments all around the world store their data. This notebook will serve as a means to parse through the api.
# </b>
#
#
# **Information on the api can be found here:** [ckan api guide](https://docs.ckan.org/en/latest/api/#example-importing-datasets-with-the-ckan-api). General information on the ckan database and its participants can be found here: [ckan official website](https://ckan.org).
#
# requests documentation: [here](https://requests.readthedocs.io/en/latest/)
#
# pandas documentation: [here](https://pandas.pydata.org/docs/)

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Using Requests to access the API
#
# The code below gives an example of using requests to pull from an api, as well as give an example of generally how this data is unpacked.

# %%
ckan_url = "http://catalog.data.gov/api/3/action/package_list"

api_token = "45tYhqFq71zd3xYo29eMgLESXiNml4Xxm9JfMmTl"

auth = {
    'X-Api-Key': api_token
}

response = requests.get(url = ckan_url,
                        headers = auth)

assert response.status_code == 200

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# The particular request above gets the data catalog for all data.gov publicly available datasets, the catalog itself looks like this:

# %%
response_dict = response.json()

# %% [markdown]
# This is a lot of info, we probably want to see the keys, and maybe even just a list of the dataset, sourcename, and url, we can do this by first looking at the column names

# %%
response_dict.keys()
# Out:
# dict_keys(['help', 'success', 'result'])

# %% [markdown]
# ### Note: To get help...

# %%
help_url = response_dict['help']

help_response = requests.get(url = help_url,
                           headers = auth)

assert help_response.status_code == 200

print(help_response.json()['result'].replace('`','\''))
# Out:
#     Searches for packages satisfying a given search criteria.
#
#     This action accepts solr search query parameters (details below), and
#     returns a dictionary of results, including dictized datasets that match
#     the search criteria, a search count and also facet information.
#
#     **Solr Parameters:**
#
#     For more in depth treatment of each paramter, please read the
#     'Solr Documentation
#     <https://lucene.apache.org/solr/guide/6_6/common-query-parameters.html>'_.
#
#     This action accepts a *subset* of solr's search query parameters:
#
#
#     :param q: the solr query.  Optional.  Default: ''"*:*"''
#     :type q: string
#     :param fq: any filter queries to apply.  Note: ''+site_id:{ckan_site_id}''
#         is added to this string prior to the query being executed.
#     :type fq: string
#     :param fq_list: additional filter queries to apply.
#     :type fq_list: list of strings
#     :param sort: sorting of the search results.  Optional.  Default:
#         '''score desc, metadata_modified desc'''.  As per the solr
#         documentation, this is a comma-separated string of field names and
#         sort-orderings.
#     :type sort: string
#     :param rows: the maximum number of matching rows (datasets) to return.
#         (optional, default: ''10'', upper limit: ''1000'' unless set in
#         site's configuration ''ckan.search.rows_max'')
#     :type rows: int
#     :param start: the offset in the complete result for where the set of
#         returned datasets should begin.
#     :type start: int
#     :param facet: whether to enable faceted results.  Default: ''True''.
#     :type facet: string
#     :param facet.mincount: the minimum counts for facet fields should be
#         included in the results.
#     :type facet.mincount: int
#     :param facet.limit: the maximum number of values the facet fields return.
#         A negative value means unlimited. This can be set instance-wide with
#         the :ref:'search.facets.limit' config option. Default is 50.
#     :type facet.limit: int
#     :param facet.field: the fields to facet upon.  Default empty.  If empty,
#         then the returned facet information is empty.
#     :type facet.field: list of strings
#     :param include_drafts: if ''True'', draft datasets will be included in the
#         results. A user will only be returned their own draft datasets, and a
#         sysadmin will be returned all draft datasets. Optional, the default is
#         ''False''.
#     :type include_drafts: bool
#     :param include_deleted: if ''True'', deleted datasets will be included in the
#         results (site configuration "ckan.search.remove_deleted_packages" must
#         be set to False). Optional, the default is ''False''.
#     :type include_deleted: bool
#     :param include_private: if ''True'', private datasets will be included in
#         the results. Only private datasets from the user's organizations will
#         be returned and sysadmins will be returned all private datasets.
#         Optional, the default is ''False''.
#     :type include_private: bool
#     :param use_default_schema: use default package schema instead of
#         a custom schema defined with an IDatasetForm plugin (default: ''False'')
#     :type use_default_schema: bool
#
#
#     The following advanced Solr parameters are supported as well. Note that
#     some of these are only available on particular Solr versions. See Solr's
#     'dismax'_ and 'edismax'_ documentation for further details on them:
#
#     ''qf'', ''wt'', ''bf'', ''boost'', ''tie'', ''defType'', ''mm''
#
#
#     .. _dismax: http://wiki.apache.org/solr/DisMaxQParserPlugin
#     .. _edismax: http://wiki.apache.org/solr/ExtendedDisMax
#
#
#     **Examples:**
#
#     ''q=flood'' datasets containing the word 'flood', 'floods' or 'flooding'
#     ''fq=tags:economy'' datasets with the tag 'economy'
#     ''facet.field=["tags"] facet.limit=10 rows=0'' top 10 tags
#
#     **Results:**
#
#     The result of this action is a dict with the following keys:
#
#     :rtype: A dictionary with the following keys
#     :param count: the number of results found.  Note, this is the total number
#         of results found, not the total number of results returned (which is
#         affected by limit and row parameters used in the input).
#     :type count: int
#     :param results: ordered list of datasets matching the query, where the
#         ordering defined by the sort parameter used in the query.
#     :type results: list of dictized datasets.
#     :param facets: DEPRECATED.  Aggregated information about facet counts.
#     :type facets: DEPRECATED dict
#     :param search_facets: aggregated information about facet counts.  The outer
#         dict is keyed by the facet field name (as used in the search query).
#         Each entry of the outer dict is itself a dict, with a "title" key, and
#         an "items" key.  The "items" key's value is a list of dicts, each with
#         "count", "display_name" and "name" entries.  The display_name is a
#         form of the name that can be used in titles.
#     :type search_facets: nested dict of dicts.
#
#     An example result: ::
#
#      {'count': 2,
#       'results': [ { <snip> }, { <snip> }],
#       'search_facets': {u'tags': {'items': [{'count': 1,
#                                              'display_name': u'tolstoy',
#                                              'name': u'tolstoy'},
#                                             {'count': 2,
#                                              'display_name': u'russian',
#                                              'name': u'russian'}
#                                            ]
#                                  }
#                        }
#      }
#
#     **Limitations:**
#
#     The full solr query language is not exposed, including.
#
#     fl
#         The parameter that controls which fields are returned in the solr
#         query.
#         fl can be  None or a list of result fields, such as
#         ['id', 'extras_custom_field'].
#         if fl = None, datasets are returned as a list of full dictionary.

# %% [markdown]
# ### Continuing with unpacking datasets using the Solr query parameters

# %%
# This function will be used to render api data in chunks
class TooMuchError(Exception):
    pass


def getLimits():
    response = requests.get('http://catalog.data.gov/api/3',
                           headers = auth)
    print(response.headers)
    rate_limits = {
        'rate_limit': response.headers.get("X-RateLimit-Limit"),
        'rate_limit_remaining': response.headers.get("X-RateLimit-Remaining"),
        'rate_limit_reset':response.headers.get("X-RateLimit-Reset")
    }
    return rate_limits

def hitMetadata(query, **kwargs):
    if 'auth' not in kwargs.keys():
        print("¡you need a key!")
    #init params
    params = {
        'fq': query,
        'rows': 15
    }
    #init start
    if 'start' in kwargs.keys():
        params['start'] = kwargs['start']
    else:
        params['start'] = 0

    #get request
    response = requests.get(url = kwargs['url'], 
                            params = params,
                            headers = kwargs['auth'])
    #pass status
    assert response.status_code == 200

    #get json dump
    json_dump = response.json()

    #paginate
    kwargs['start'] += params['rows']

    #try results 
    try:
        kwargs['results'] += json_dump['result']['results']
    except:
        kwargs['results'] = json_dump['result']['results']
    #continue recursion if necessary
    print(kwargs['start'])
    
    if json_dump['result']['results']:
        hitMetadata(query, url=kwargs['url'], auth=kwargs['auth'], start=kwargs['start'], results=kwargs['results'])

    #if not return results
    return kwargs['results']
    # if json_dump['result']['count'] >= 100:
    #     error_message = '''
    #     You are trying to retrieve to much data at once and you are going to get me banned from the api, 
    #     break your query up into more bite size chunks and do this again, or if your are using my key
    #     (or yours) and you are trying to hit the api wait ten minutes between each large query
    #     '''
    #     raise TooMuchError(error_message)

# %%
query = 'organization.name = nasa'
'2a9ff0f7-11d8-41c4-b017-52c4fe0f260a'
metadata = hitMetadata(query, url = ckan_url, auth = auth, start = 0)
# Out:
# 15
# 30
# 45
# 60
# 75
# 90
# 105
# 120
# 135
# 150
# 165
# 180
# 195
# 210
# 225
# 240
# 255
# 270
# 285
# 300
# 315
# 330
# 345
# 360
# 375
# 390
# 405
# 420
# 435
# 450
# 465
# 480
# 495
# 510
# 525
# 540
# 555
# 570
# 585
# 600
# 615
# 630
# 645
# 660
# 675
# 690
# 705
# 720
# 735
# 750
# 765
# 780
# 795
# 810
# 825
# 840
# 855
# 870
# 885
# 900
# 915
# 930
# 945
# 960
# 975
# 990
# 1005
# 1020
# 1035
# 1050
# 1065
# 1080
# 1095
# 1110
# 1125
# 1140
# 1155
# 1170
# 1185
# 1200
# 1215
# 1230
# 1245
# 1260
# 1275
# 1290
# 1305
# 1320
# 1335
# 1350
# 1365
# 1380
# 1395
# 1410
# 1425
# 1440
# 1455
# 1470

# %%
metadata[:100]
# Out:
# [{'author': None,
#   'author_email': None,
#   'creator_user_id': '1ecd1fb1-1be6-46bb-b90d-07a0762ed104',
#   'id': '74780733-0e8b-48cc-9a22-8daa9e6ab2f9',
#   'isopen': False,
#   'license_id': None,
#   'license_title': None,
#   'maintainer': None,
#   'maintainer_email': None,
#   'metadata_created': '2023-08-30T04:56:11.061072',
#   'metadata_modified': '2023-08-30T04:56:11.061077',
#   'name': 'enviroatlas-potential-evapotranspiration-1950-2099-for-the-conterminous-united-states1',
#   'notes': 'The EnviroAtlas Climate Scenarios were generated from NASA Earth Exchange (NEX) Downscaled Climate Projections (NEX-DCP30) ensemble averages (the average of over 30 available climate models) for each of the four representative concentration pathways (RCP) for the contiguous U.S. at 30 arc-second (approx. 800 m2) spatial resolution. In addition to the three climate variables provided by the NEX-DCP30 dataset (minimum monthly temperature, maximum monthly temperature, and precipitation) a corresponding estimate of potential evapotranspiration (PET) was developed to match the spatial and temporal scales of the input dataset. PET represents the cumulative amount of water returned to the atmosphere due to evaporation from Earthâ\x80\x99s surface and plant transpiration under ideal circumstances (i.e., a vegetated surface shading the ground and unlimited water supply). PET was calculated using the Hamon PET equation (Hamon, 1961) and CBM model for daylength (Forsythe et al. 1995) for the 4 RCPs (2.6, 4.5, 6.0, 8.5) and organized by season (Winter, Spring, Summer, and Fall) and annually for the years 2006 â\x80\x93 2099. Additionally, PET was calculated for the ensemble average of all historic runs and organized similarly for the years 1950 â\x80\x93 2005. This dataset was produced by the US EPA to support research and online mapping activities related to EnviroAtlas. EnviroAtlas (https://www.epa.gov/enviroatlas) allows the user to interact with a web-based, easy-to-use, mapping application to view and analyze multiple ecosystem services for the contiguous United States. The dataset is available as downloadable data (https://cds.nccs.nasa.gov/nex/) or as an EnviroAtlas map service. Additional descriptive information about each attribute in this dataset can be found in its associated EnviroAtlas Fact Sheet (https://www.epa.gov/enviroatlas/enviroatlas-fact-sheets).',
#   'num_resources': 4,
#   'num_tags': 59,
#   'organization': {'id': '82b85475-f85d-404a-b95b-89d1a42e9f6b',
#    'name': 'epa-gov',
#    'title': 'U.S. Environmental Protection Agency',
#    'type': 'organization',
#    'description': 'Our mission is to protect human health and the environment. ',
#    'image_url': 'https://edg.epa.gov/EPALogo.svg',
#    'created': '2020-11-10T15:10:42.298896',
#    'is_organization': True,
#    'approval_status': 'approved',
#    'state': 'active'},
#   'owner_org': '82b85475-f85d-404a-b95b-89d1a42e9f6b',
#   'private': False,
#   'state': 'active',
#   'title': 'EnviroAtlas - Potential Evapotranspiration 1950 - 2099 for the Conterminous United States',
#   'type': 'dataset',
#   'url': None,
#   'version': None,
#   'extras': [{'key': 'guid',
#     'value': '{91dc2cb5-0b7e-49f7-8a8a-832298fd5b85}'},
#    {'key': 'spatial_harvester', 'value': True},
#    {'key': 'spatial-reference-system', 'value': ''},
#    {'key': 'dataset-reference-date',
#     'value': '[{"type": "publication", "value": "2016-05-31"}]'},
#    {'key': 'metadata-language', 'value': 'eng; USA'},
#    {'key': 'metadata-date', 'value': '2016-05-31'},
#    {'key': 'coupled-resource', 'value': '[]'},
#    {'key': 'contact-email', 'value': 'EnviroAtlas@epa.gov'},
#    {'key': 'frequency-of-update', 'value': 'asNeeded'},
#    {'key': 'spatial-data-service-type', 'value': ''},
#    {'key': 'progress', 'value': 'completed'},
#    {'key': 'resource-type', 'value': 'dataset'},
#    {'key': 'licence',
#     'value': '["https://edg.epa.gov/EPA_Data_License.html"]'},
#    {'key': 'licence_url',
#     'value': 'https://edg.epa.gov/EPA_Data_License.html'},
#    {'key': 'access_constraints',
#     'value': '["Use Constraints: None. Please check sources, scale, accuracy, currency and other available information. Please confirm that you are using the most recent copy of both data and metadata. Acknowledgement of the EPA would be appreciated.", "Access Constraints: None"]'},
#    {'key': 'temporal-extent-begin', 'value': '1950-01-01'},

#     'state': 'active',
#     'vocabulary_id': None},
#    {'display_name': 'virginia',
#     'id': '9eba7ccb-8234-4f34-9f78-a51ea87bf46d',
#     'name': 'virginia',
#     'state': 'active',
#     'vocabulary_id': None},
#    {'display_name': 'washington',
#     'id': '75eae539-9b91-4cf6-b3ac-f9383fd16373',
#     'name': 'washington',
#     'state': 'active',
#     'vocabulary_id': None},
#    {'display_name': 'washington dc',
#     'id': '1875d308-ac89-4fce-833f-5f1bccce6632',
#     'name': 'washington dc',
#     'state': 'active',
#     'vocabulary_id': None},
#    {'display_name': 'west virginia',
#     'id': '871dd60b-0be4-44cb-9d0f-f276ab2e31c0',
#     'name': 'west virginia',
#     'state': 'active',
#     'vocabulary_id': None},
#    {'display_name': 'wisconsin',
#     'id': '467fd4c1-1bba-45c3-b24c-dcd0869fd0dc',
#     'name': 'wisconsin',
#     'state': 'active',
#     'vocabulary_id': None},
#    {'display_name': 'wyoming',
#     'id': '99cbf63b-3249-4862-8246-4641ce50f2b8',
#     'name': 'wyoming',
#     'state': 'active',
#     'vocabulary_id': None}],
#   'groups': [],
#   'relationships_as_subject': [],
#   'relationships_as_object': []},
#  {'author': None,
#   'author_email': None,
#   'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#   'id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#   'isopen': False,
#   'license_id': None,
#   'license_title': None,
#   'maintainer': None,
#   'maintainer_email': None,
#   'metadata_created': '2020-12-04T04:37:28.037972',
#   'metadata_modified': '2023-12-01T21:17:14.174214',
#   'name': 'chemical-benthic-organisms-and-other-data-from-moored-current-meter-casts-and-other-instruments',
#   'notes': 'Chemical, benthic organisms, and other data were collected using moored current meter casts and other instruments in the Gulf of Mexico from November 11, 1983 to November 13, 1984. Data were submitted by Alaska Research Associates, Inc., as part of the Gulf of Mexico North Continental Slope Study (MNCSS) project. Data has been processed by NODC to the NODC standard F004 Water Physics and Chemistry, F123 Fish Shellfish Resource, and F132 Benthic Organisms formats.\n\nThe F004 format is used for data from measurements and analyses of physical and chemical characteristics of the water column. Among chemical parameters that may be recorded are salinity, pH, and concentration of oxygen, ammonia, nitrate, phosphate, chlorophyll, and suspended solids. Physical parameters that may be recorded include temperature, density (sigma-t), transmissivity, and current velocity (east-west and north-south components). Cruise and station information, including environmental conditions of the study site at the time of observations, is also included.\n\nThe F123 format is used for data from field sampling of marine fish and shellfish. The data derive from analysis of midwater or bottom tow catches and provide information on population density and distribution. Cruise information, position, date, time, gear type, fishing distance and duration, and number of hauls are reported for each survey. Environmental data may include meteorological conditions, surface and bottom temperature and salinity, and current direction and speed. Bottom trawl or other gear dimensions and characteristics are also reported. Catch statistics (e.g., weight, volume, number of fish per unit volume) may be reported for both total haul and for individual species. Biological characteristics of selected specimens, predator/ prey information (from stomach contents analysis), and growth data may also be included. A text record is available for comments.\n\nThe F132 format contains data from field sampling or surveys of bottom dwelling marine organisms. The data provide information on species abundance, distribution, and biomass; they may have been collected by point sampling (grab or core), by tow (dredge, trawl or net), by photographic surveys, or by other methods. Cruise information such as vessel, start and end dates, investigator, and institution/agency; station numbers, positions and times; and equipment and methods are reported for each survey. Environmental data reported at each sampling site may include meteorological and sea surface conditions; surface and bottom temperature, salinity and dissolved oxygen; and sediment characteristics. Number of individual organisms and total weight of organisms is reported for each species. A text record is available for comments.',
#   'num_resources': 13,
#   'num_tags': 1,
#   'organization': {'id': '5f4f1195-e770-4a2a-8f75-195cd98860ce',
#    'name': 'noaa-gov',
#    'title': 'National Oceanic and Atmospheric Administration, Department of Commerce',
#    'type': 'organization',
#    'description': '',
#    'image_url': 'https://fortress.wa.gov/dfw/score/score/images/noaa_logo.png',
#    'created': '2020-11-10T15:36:13.098184',
#    'is_organization': True,
#    'approval_status': 'approved',
#    'state': 'active'},
#   'owner_org': '5f4f1195-e770-4a2a-8f75-195cd98860ce',
#   'private': False,
#   'state': 'active',
#   'title': 'Chemical, benthic organisms, and other data from moored current meter casts and other instruments in the Gulf of Mexico during the Gulf of Mexico North Continental Slope Study (MNCSS) project, 1983-11-11 to 1984-11-13 (NCEI Accession 8400119)',
#   'type': 'dataset',
#   'url': None,
#   'version': None,
#   'extras': [{'key': 'guid', 'value': 'gov.noaa.nodc:8400119'},
#    {'key': 'spatial_harvester', 'value': True},
#    {'key': 'spatial-reference-system', 'value': ''},
#    {'key': 'dataset-reference-date',
#     'value': '[{"type": "publication", "value": "2003-10-24"}, {"type": "revision", "value": "2023-02-10"}]'},
#    {'key': 'metadata-language', 'value': 'eng'},
#    {'key': 'metadata-date', 'value': '2023-10-31T21:36:36Z'},
#    {'key': 'coupled-resource', 'value': '[]'},
#    {'key': 'contact-email', 'value': 'ncei.info@noaa.gov'},
#    {'key': 'frequency-of-update', 'value': 'asNeeded'},
#    {'key': 'spatial-data-service-type', 'value': ''},
#    {'key': 'progress', 'value': 'completed'},
#    {'key': 'resource-type', 'value': 'dataset'},
#    {'key': 'licence', 'value': '["accessLevel: Public"]'},
#    {'key': 'access_constraints',
#     'value': '["Cite as: Brown, Murray; LGL Ltd. > Alaska Research Associates, Inc. (2003). Chemical, benthic organisms, and other data from moored current meter casts and other instruments in the Gulf of Mexico during the Gulf of Mexico North Continental Slope Study (MNCSS) project, 1983-11-11 to 1984-11-13 (NCEI Accession 8400119). [indicate subset used]. NOAA National Centers for Environmental Information. Dataset. https://www.ncei.noaa.gov/archive/accession/8400119. Accessed [date].", "Use liability: NOAA and NCEI cannot provide any warranty as to the accuracy, reliability, or completeness of furnished data. Users assume responsibility to determine the usability of these data. The user is responsible for the results of any application of this data for other than its intended purpose."]'},
#    {'key': 'graphic-preview-file',
#     'value': 'https://www.ncei.noaa.gov/access/metadata/landing-page/bin/gfx?id=gov.noaa.nodc:8400119'},
#    {'key': 'graphic-preview-description', 'value': 'Preview graphic'},
#    {'key': 'graphic-preview-type', 'value': 'PNG'},
#    {'key': 'temporal-extent-begin', 'value': '1983-11-11'},
#    {'key': 'temporal-extent-end', 'value': '1984-11-13'},
#    {'key': 'responsible-party',
#     'value': '[{"name": "", "roles": ["pointOfContact"]}]'},
#    {'key': 'bbox-east-long', 'value': '-89.55'},
#    {'key': 'bbox-north-lat', 'value': '28.09'},
#    {'key': 'bbox-south-lat', 'value': '26.91'},
#    {'key': 'bbox-west-long', 'value': '-90.32'},
#    {'key': 'lineage', 'value': ''},
#    {'key': 'metadata_type', 'value': 'geospatial'},
#    {'key': 'old-spatial',
#     'value': '{"type": "Polygon", "coordinates": [[[-90.32, 26.91], [-89.55, 26.91], [-89.55, 28.09], [-90.32, 28.09], [-90.32, 26.91]]]}'},
#    {'key': 'spatial',
#     'value': '{"type": "Polygon", "coordinates": [[[-90.32, 26.91], [-89.55, 26.91], [-89.55, 28.09], [-90.32, 28.09], [-90.32, 26.91]]]}'},
#    {'key': 'harvest_object_id',
#     'value': '36afa2ae-a5e1-43e0-8dbb-db1613da9249'},
#    {'key': 'harvest_source_id',
#     'value': 'c084a438-6f6b-470d-93e0-16aeddb9f513'},
#    {'key': 'harvest_source_title', 'value': 'NOAA/NESDIS/ncei/accessions'}],
#   'resources': [{'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203811',
#     'description': 'Navigate directly to the URL for a descriptive web page with download links.',
#     'format': '',
#     'hash': '',
#     'id': 'f07d66c4-103b-4545-b687-8876e48a27b5',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.183716',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'NCEI Dataset Landing Page',
#     'package_id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#     'position': 0,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/8400119',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203817',
#     'description': 'Navigate directly to the URL for a descriptive web page with download links.',
#     'format': '',
#     'hash': '',
#     'id': '384cb7b1-5344-42ad-b2d1-94a3668dd5c1',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.184004',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'Descriptive Information',
#     'package_id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#     'position': 1,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/oas/8400119',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203820',
#     'description': 'Navigate directly to the URL for data access and direct download.',
#     'format': '',
#     'hash': '',
#     'id': '9750cd11-e8d1-45b7-a867-f3408ca7be08',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.184290',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'HTTPS',
#     'package_id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#     'position': 2,
#     'resource_locator_function': 'download',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/download/8400119',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203823',
#     'description': 'These data are available through the File Transfer Protocol (FTP). FTP is no longer supported by most internet browsers. You may copy and paste the FTP link to the data into an FTP client (e.g., FileZilla or WinSCP).',
#     'format': '',
#     'hash': '',
#     'id': '65fe8f7e-6714-4a1b-bcc6-b9337fdf1533',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.184548',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'FTP',
#     'package_id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#     'position': 3,
#     'resource_locator_function': 'download',
#     'resource_locator_protocol': 'FTP',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'ftp://ftp-oceans.ncei.noaa.gov/nodc/archive/arc0001/8400119/',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203826',
#     'description': 'Information for contacts at NCEI.',
#     'format': '',
#     'hash': '',
#     'id': 'ade9dce2-1e5e-47f7-90a4-2446ab1b1e50',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.184787',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 

#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203839',
#     'description': 'Global Change Master Directory (GCMD). 2023. GCMD Keywords, Version 17. Greenbelt, MD: Earth Science Data and Information System, Earth Science Projects Division, Goddard Space Flight Center (GSFC), National Aeronautics and Space Administration (NASA). URL (GCMD Keyword Forum Page): https://forum.earthdata.nasa.gov/app.php/tag/GCMD+Keywords',
#     'format': '',
#     'hash': '',
#     'id': '8d99c3ed-dae0-4093-b05f-d0eb0670d496',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.185583',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'GCMD Keyword Forum Page',
#     'package_id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#     'position': 9,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://forum.earthdata.nasa.gov/app.php/tag/GCMD%2BKeywords',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203842',
#     'description': 'Global Change Master Directory (GCMD). 2023. GCMD Keywords, Version 17. Greenbelt, MD: Earth Science Data and Information System, Earth Science Projects Division, Goddard Space Flight Center (GSFC), National Aeronautics and Space Administration (NASA). URL (GCMD Keyword Forum Page): https://forum.earthdata.nasa.gov/app.php/tag/GCMD+Keywords',
#     'format': '',
#     'hash': '',
#     'id': '78e38853-e687-4e29-be46-b477b574ed19',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.185703',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'GCMD Keyword Forum Page',
#     'package_id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#     'position': 10,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://forum.earthdata.nasa.gov/app.php/tag/GCMD%2BKeywords',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203844',
#     'description': 'documentation',
#     'format': '',
#     'hash': '',
#     'id': 'df89de12-f9a5-447c-b67f-0965affae280',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.185829',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'https://www.ncei.noaa.gov/archive/accession/0189890',
#     'package_id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#     'position': 11,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/0189890',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-12-01T21:17:14.203847',
#     'description': 'Institution web page',
#     'format': '',
#     'hash': '',
#     'id': '5a0126ce-0843-40f3-b715-44720663e8c1',
#     'last_modified': None,
#     'metadata_modified': '2023-12-01T21:17:14.185947',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'US National Oceanographic Data Center website',
#     'package_id': '999cbfb1-4ecd-4591-adfe-dc4ef037564e',
#     'position': 12,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.nodc.noaa.gov/',
#     'url_type': None}],
#   'tags': [{'display_name': 'oceanography',
#     'id': '870d5b55-1fe2-4990-848f-08ad8e71b310',
#     'name': 'oceanography',
#     'state': 'active',
#     'vocabulary_id': None}],
#   'groups': [],
#   'relationships_as_subject': [],
#   'relationships_as_object': []},
#  {'author': None,
#   'author_email': None,
#   'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#   'id': '6a62c165-9b19-4ced-874a-824966a89b51',
#   'isopen': False,
#   'license_id': None,
#   'license_title': None,
#   'maintainer': None,
#   'maintainer_email': None,
#   'metadata_created': '2021-07-02T20:29:11.386487',
#   'metadata_modified': '2023-11-01T22:37:57.474574',
#   'name': 'sub-daily-meteorological-data-collected-at-montevergine-observatory-southern-apennines-italy-fr4',
#   'notes': 'This work presents the rescue of the sub-daily meteorological observations collected at Montevergine Observatory (hereafter, MVOBS) from 1884 to 1963. MVOBS is located on the Southern Apennines (40.936502 N, 14.729150 E) at an elevation of 1280 m above sea level (asl). The sub-daily dataset consists of three daily observations (performed at about 8:00, 14:00 and 20:00 hours) of several atmospheric variables. The data, originally available only on paper, have been digitized following the World Meteorological Organization standard practices. The following variables: dry bulb temperature, wet bulb temperature, water vapor pressure, relative humidity, atmospheric pressure, cloud cover, rainfall, snowfall, equivalent liquid precipitation underwent a dedicated quality control process. After a cross-check based on a manual inspection, three consecutive quality control tests have been applied:- Gross error test: verifies if the data are within acceptable range limits. Data passing this test have been labeled as QC = 1, otherwise they have been labeled as QC = 8 (bad data) or QC = 9 (suspicious data);- Tolerance test: flags the values that are above or below monthly climatological limits, defined according to probability distribution model. This test has been applied to all investigated parameters, except of cloud cover. Data that have passed gross and tolerance test have been labeled as QC = 2;- Temporal coherency test: checks the rate of change, flagging unrealistic jumps in adjacent values This test has not been applied to rainfall, snowfall and cloud cover records. Data that have passed gross, tolerance and temporal coherency tests have been labeled as QC = 3. The quality flag value is associated to each measurement/observation and is indicated in a dedicated column for each variable. Furthermore, a set of additional parameters, not statistically quality controlled, is provided including the following  variables: cloud type, precipitation type, wind direction, wind speed, cloud direction, snow depth, low level cloud base height and low level cloud cover. Historical notes from the observer in the original language (Italian) are also provided.\n\nTime coverage may vary according to the parameter, missing data are represented by NaN. Two different version of the dataset are provided in excel format: "subdaily_data_MVOBS_raw" includes all the observed parameters without any quality control procedure. "subdaily_data_MVOBS_QC_VARIABLES" including data from all the variables that have been checked with the statistical quality control procedures.',
#   'num_resources': 17,
#   'num_tags': 14,
#   'organization': {'id': '5f4f1195-e770-4a2a-8f75-195cd98860ce',
#    'name': 'noaa-gov',
#    'title': 'National Oceanic and Atmospheric Administration, Department of Commerce',
#    'type': 'organization',
#    'description': '',
#    'image_url': 'https://fortress.wa.gov/dfw/score/score/images/noaa_logo.png',
#    'created': '2020-11-10T15:36:13.098184',
#    'is_organization': True,
#    'approval_status': 'approved',
#    'state': 'active'},
#   'owner_org': '5f4f1195-e770-4a2a-8f75-195cd98860ce',
#   'private': False,
#   'state': 'active',
#   'title': 'Sub-daily meteorological data collected at Montevergine Observatory (Southern Apennines), Italy from 1884-01-01 to 1963-12-31 (NCEI Accession 0205785)',
#   'type': 'dataset',
#   'url': None,
#   'version': None,
#   'extras': [{'key': 'guid', 'value': 'gov.noaa.nodc:0205785'},
#    {'key': 'spatial_harvester', 'value': True},
#    {'key': 'spatial-reference-system', 'value': ''},
#    {'key': 'dataset-reference-date',
#     'value': '[{"type": "publication", "value": "2019-10-25"}]'},
#    {'key': 'metadata-language', 'value': 'eng'},
#    {'key': 'metadata-date', 'value': '2023-08-30T13:03:14Z'},
#    {'key': 'coupled-resource', 'value': '[]'},
#    {'key': 'contact-email', 'value': 'ncei.info@noaa.gov'},
#    {'key': 'frequency-of-update', 'value': 'asNeeded'},
#    {'key': 'spatial-data-service-type', 'value': ''},
#    {'key': 'progress', 'value': 'completed'},
#    {'key': 'resource-type', 'value': 'dataset'},
#    {'key': 'licence', 'value': '["accessLevel: Public"]'},
#    {'key': 'access_constraints',
#     'value': '["Cite as: Capozzi, Vincenzo; Cotroneo, Yuri; Castagno, Pasquale; De Vivo, Carmela; Komar, Andrew; Guariglia, Riccardo; Budillon, Giorgio (2019). Sub-daily meteorological data collected at Montevergine Observatory (Southern Apennines), Italy from 1884-01-01 to 1963-12-31 (NCEI Accession 0205785). [indicate subset used]. NOAA National Centers for Environmental Information. Dataset. https://doi.org/10.25921/cx3g-rj98. Accessed [date].", "Use liability: NOAA and NCEI cannot provide any warranty as to the accuracy, reliability, or completeness of furnished data. Users assume responsibility to determine the usability of these data. The user is responsible for the results of any application of this data for other than its intended purpose."]'},
#    {'key': 'graphic-preview-file',
#     'value': 'https://www.ncei.noaa.gov/access/metadata/landing-page/bin/gfx?id=gov.noaa.nodc:0205785'},
#    {'key': 'graphic-preview-description', 'value': 'Preview graphic'},
#    {'key': 'graphic-preview-type', 'value': 'PNG'},
#    {'key': 'temporal-extent-begin', 'value': '1884-01-01'},
#    {'key': 'temporal-extent-end', 'value': '1963-12-31'},
#    {'key': 'responsible-party',
#     'value': '[{"name": "", "roles": ["pointOfContact"]}]'},
#    {'key': 'bbox-east-long', 'value': '14.72915'},
#    {'key': 'bbox-north-lat', 'value': '40.936502'},
#    {'key': 'bbox-south-lat', 'value': '40.936502'},
#    {'key': 'bbox-west-long', 'value': '14.72915'},
#    {'key': 'lineage', 'value': ''},
#    {'key': 'metadata_type', 'value': 'geospatial'},
#    {'key': 'old-spatial',
#     'value': '{"type": "Point", "coordinates": [14.72915, 40.936502]}'},
#    {'key': 'spatial',
#     'value': '{"type": "Point", "coordinates": [14.72915, 40.936502]}'},
#    {'key': 'harvest_object_id',
#     'value': 'b4346b38-de8f-47e0-8fae-c11cc6e70d1c'},
#    {'key': 'harvest_source_id',
#     'value': 'c084a438-6f6b-470d-93e0-16aeddb9f513'},
#    {'key': 'harvest_source_title', 'value': 'NOAA/NESDIS/ncei/accessions'}],
#   'resources': [{'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:37:57.544689',
#     'description': 'Navigate directly to the URL for a descriptive web page with download links.',
#     'format': '',
#     'hash': '',
#     'id': 'b3ecde96-39bd-4ae3-8a70-9a64b681ab27',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:37:57.483323',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'NCEI Dataset Landing Page',
#     'package_id': '6a62c165-9b19-4ced-874a-824966a89b51',
#     'position': 0,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://doi.org/10.25921/cx3g-rj98',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:37:57.544693',
#     'description': 'Navigate directly to the URL for a descriptive web page with download links.',
#     'format': '',
#     'hash': '',
#     'id': 'bb06bfb6-4956-445f-91fd-d705b63857b4',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:37:57.483487',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'Descriptive Information',
#     'package_id': '6a62c165-9b19-4ced-874a-824966a89b51',
#     'position': 1,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/oas/205785',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:37:57.544695',
#     'description': 'Navigate directly to the URL for data access and direct download.',
#     'format': '',
#     'hash': '',
#     'id': 'e54b15f9-ce83-48dc-81ee-39f15536a622',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:37:57.483610',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'HTTPS',
#     'package_id': '6a62c165-9b19-4ced-874a-824966a89b51',
#     'position': 2,
#     'resource_locator_function': 'download',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/download/205785',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:37:57.544697',
#     'description': 'These data are available through the File Transfer Protocol (FTP). FTP is no longer supported by most internet browsers. You may copy and paste the FTP link to the data into an FTP client (e.g., FileZilla or WinSCP).',
#     'format': '',
#     'hash': '',
#     'id': '0104f786-04ab-4010-953f-440cfaf09f4d',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:37:57.483727',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'FTP',
#     'package_id': '6a62c165-9b19-4ced-874a-824966a89b51',
#     'position': 3,
#     'resource_locator_function': 'download',
#     'resource_locator_protocol': 'FTP',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'ftp://ftp-oceans.ncei.noaa.gov/nodc/archive/arc0147/0205785/',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:37:57.544698',
#     'description': 'Information for contacts at NCEI.',
#     'format': '',
#     'hash': '',
#     'id': '15b6d261-b149-4db4-859c-369bdc89f3df',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:37:57.483842',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'NCEI Contact Information',
#     'package_id': '6a62c165-9b19-4ced-874a-824966a89b51',
#     'position': 4,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/contact',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:37:57.544700',
#     'description': 'Institution web page',
#     'format': '',
#     'hash': '',
#     'id': 'ea020a7a-eb52-4bcd-8e84-0c2940715f30',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:37:57.483955',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'The Parthenope University of Naples website',
#     'package_id': '6a62c165-9b19-4ced-874a-824966a89b51',
#     'position': 5,
# ...
#   'private': False,
#   'state': 'active',
#   'title': 'Physical, chemical, net haul, bird surveys, and other observations (BIOMASS data) from the British Antarctic Survey FIBEX and SIBEX Projects from 01 November 1980 to 30 April 1985 (NCEI Accession 9400053)',
#   'type': 'dataset',
#   'url': None,
#   'version': None,
#   'extras': [{'key': 'guid', 'value': 'gov.noaa.nodc:9400053'},
#    {'key': 'spatial_harvester', 'value': True},
#    {'key': 'spatial-reference-system', 'value': ''},
#    {'key': 'dataset-reference-date',
#     'value': '[{"type": "publication", "value": "2002-11-19"}, {"type": "revision", "value": "2013-03-18"}]'},
#    {'key': 'metadata-language', 'value': 'eng'},
#    {'key': 'metadata-date', 'value': '2023-05-15T16:54:00Z'},
#    {'key': 'coupled-resource', 'value': '[]'},
#    {'key': 'contact-email', 'value': 'ncei.info@noaa.gov'},
#    {'key': 'frequency-of-update', 'value': 'asNeeded'},
#    {'key': 'spatial-data-service-type', 'value': ''},
#    {'key': 'progress', 'value': 'completed'},
#    {'key': 'resource-type', 'value': 'dataset'},
#    {'key': 'licence', 'value': '["accessLevel: Public"]'},
#    {'key': 'access_constraints',
#     'value': '["Cite as: Thorley, Mark; British Antarctic Survey (2002). Physical, chemical, net haul, bird surveys, and other observations (BIOMASS data) from the British Antarctic Survey FIBEX and SIBEX Projects from 01 November 1980 to 30 April 1985 (NCEI Accession 9400053). [indicate subset used]. NOAA National Centers for Environmental Information. Dataset. https://www.ncei.noaa.gov/archive/accession/9400053. Accessed [date].", "Use liability: NOAA and NCEI cannot provide any warranty as to the accuracy, reliability, or completeness of furnished data. Users assume responsibility to determine the usability of these data. The user is responsible for the results of any application of this data for other than its intended purpose."]'},
#    {'key': 'graphic-preview-file',
#     'value': 'https://www.ncei.noaa.gov/access/metadata/landing-page/bin/gfx?id=gov.noaa.nodc:9400053'},
#    {'key': 'graphic-preview-description', 'value': 'Preview graphic'},
#    {'key': 'graphic-preview-type', 'value': 'PNG'},
#    {'key': 'temporal-extent-begin', 'value': '1980-11-01'},
#    {'key': 'temporal-extent-end', 'value': '1985-04-30'},
#    {'key': 'responsible-party',
#     'value': '[{"name": "", "roles": ["pointOfContact"]}]'},
#    {'key': 'bbox-east-long', 'value': '93.012'},
#    {'key': 'bbox-north-lat', 'value': '-59.99'},
#    {'key': 'bbox-south-lat', 'value': '-69.023'},
#    {'key': 'bbox-west-long', 'value': '-66.52'},
#    {'key': 'lineage', 'value': ''},
#    {'key': 'metadata_type', 'value': 'geospatial'},
#    {'key': 'old-spatial',
#     'value': '{"type": "Polygon", "coordinates": [[[-66.52, -69.023], [93.012, -69.023], [93.012, -59.99], [-66.52, -59.99], [-66.52, -69.023]]]}'},
#    {'key': 'spatial',
#     'value': '{"type": "Polygon", "coordinates": [[[-66.52, -69.023], [93.012, -69.023], [93.012, -59.99], [-66.52, -59.99], [-66.52, -69.023]]]}'},
#    {'key': 'harvest_object_id',
#     'value': '1cf0f2f8-59a8-4892-b0f0-e16569c33e46'},
#    {'key': 'harvest_source_id',
#     'value': 'c084a438-6f6b-470d-93e0-16aeddb9f513'},
#    {'key': 'harvest_source_title', 'value': 'NOAA/NESDIS/ncei/accessions'}],
#   'resources': [{'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466365',
#     'description': 'Navigate directly to the URL for a descriptive web page with download links.',
#     'format': '',
#     'hash': '',
#     'id': 'ad72e42b-8fed-46b7-be64-a828ed315b1f',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.438656',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'NCEI Dataset Landing Page',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 0,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/9400053',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466370',
#     'description': 'Navigate directly to the URL for a descriptive web page with download links.',
#     'format': '',
#     'hash': '',
#     'id': '12d5cf8f-f978-45ef-8ca6-2ebce9fcce10',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.438837',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'Descriptive Information',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 1,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/oas/9400053',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466373',
#     'description': 'Navigate directly to the URL for data access and direct download.',
#     'format': '',
#     'hash': '',
#     'id': '0fbf2fdb-987f-4617-b18f-42807ede312c',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.438966',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'HTTPS',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 2,
#     'resource_locator_function': 'download',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/archive/accession/download/9400053',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466375',
#     'description': 'These data are available through the File Transfer Protocol (FTP). FTP is no longer supported by most internet browsers. You may copy and paste the FTP link to the data into an FTP client (e.g., FileZilla or WinSCP).',
#     'format': '',
#     'hash': '',
#     'id': '825b13f9-f12f-4d0a-8ab0-0e53e36413b1',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.439099',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'FTP',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 3,
#     'resource_locator_function': 'download',
#     'resource_locator_protocol': 'FTP',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'ftp://ftp-oceans.ncei.noaa.gov/nodc/archive/arc0001/9400053/',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466376',
#     'description': 'Information for contacts at NCEI.',
#     'format': '',
#     'hash': '',
#     'id': 'cd225cd2-70e5-40bb-bec1-55c465c6cd6b',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.439221',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'NCEI Contact Information',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 4,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/contact',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466378',
#     'description': 'Information for contacts at NCEI.',
#     'format': '',
#     'hash': '',
#     'id': '7247a164-24e5-4fbd-8055-a6a154fd39e2',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.439339',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'NCEI Contact Information',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 5,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://www.ncei.noaa.gov/contact',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466380',
#     'description': 'Global Change Master Directory (GCMD). 2023. GCMD Keywords, Version 16. Greenbelt, MD: Earth Science Data and Information System, Earth Science Projects Division, Goddard Space Flight Center (GSFC), National Aeronautics and Space Administration (NASA). URL (GCMD Keyword Forum Page): https://forum.earthdata.nasa.gov/app.php/tag/GCMD+Keywords',
#     'format': '',
#     'hash': '',
#     'id': '6b5465d1-d9c6-4b3f-9ea8-34ddf77d4c5f',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.439457',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'GCMD Keyword Forum Page',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 6,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://forum.earthdata.nasa.gov/app.php/tag/GCMD%2BKeywords',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466382',
#     'description': 'Global Change Master Directory (GCMD). 2023. GCMD Keywords, Version 16. Greenbelt, MD: Earth Science Data and Information System, Earth Science Projects Division, Goddard Space Flight Center (GSFC), National Aeronautics and Space Administration (NASA). URL (GCMD Keyword Forum Page): https://forum.earthdata.nasa.gov/app.php/tag/GCMD+Keywords',
#     'format': '',
#     'hash': '',
#     'id': '09ed39cc-8548-443d-98d2-cc5f79f94d88',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.439574',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'GCMD Keyword Forum Page',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 7,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://forum.earthdata.nasa.gov/app.php/tag/GCMD%2BKeywords',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466384',
#     'description': 'Global Change Master Directory (GCMD). 2023. GCMD Keywords, Version 16. Greenbelt, MD: Earth Science Data and Information System, Earth Science Projects Division, Goddard Space Flight Center (GSFC), National Aeronautics and Space Administration (NASA). URL (GCMD Keyword Forum Page): https://forum.earthdata.nasa.gov/app.php/tag/GCMD+Keywords',
#     'format': '',
#     'hash': '',
#     'id': 'c7f58603-e03a-40fe-84b4-1621b6c76fc6',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.439693',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'GCMD Keyword Forum Page',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 8,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://forum.earthdata.nasa.gov/app.php/tag/GCMD%2BKeywords',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466385',
#     'description': 'Global Change Master Directory (GCMD). 2023. GCMD Keywords, Version 16. Greenbelt, MD: Earth Science Data and Information System, Earth Science Projects Division, Goddard Space Flight Center (GSFC), National Aeronautics and Space Administration (NASA). URL (GCMD Keyword Forum Page): https://forum.earthdata.nasa.gov/app.php/tag/GCMD+Keywords',
#     'format': '',
#     'hash': '',
#     'id': '9a670be6-9c63-4690-bf71-9d46b43c5a3b',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.439811',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'GCMD Keyword Forum Page',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 9,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://forum.earthdata.nasa.gov/app.php/tag/GCMD%2BKeywords',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466387',
#     'description': 'Global Change Master Directory (GCMD). 2023. GCMD Keywords, Version 16. Greenbelt, MD: Earth Science Data and Information System, Earth Science Projects Division, Goddard Space Flight Center (GSFC), National Aeronautics and Space Administration (NASA). URL (GCMD Keyword Forum Page): https://forum.earthdata.nasa.gov/app.php/tag/GCMD+Keywords',
#     'format': '',
#     'hash': '',
#     'id': '3b31ca88-b38a-4674-95e5-07f8c356d11c',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.439928',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'GCMD Keyword Forum Page',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 10,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://forum.earthdata.nasa.gov/app.php/tag/GCMD%2BKeywords',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466389',
#     'description': 'Global Change Master Directory (GCMD). 2023. GCMD Keywords, Version 16. Greenbelt, MD: Earth Science Data and Information System, Earth Science Projects Division, Goddard Space Flight Center (GSFC), National Aeronautics and Space Administration (NASA). URL (GCMD Keyword Forum Page): https://forum.earthdata.nasa.gov/app.php/tag/GCMD+Keywords',
#     'format': '',
#     'hash': '',
#     'id': 'b0713a17-bb1f-493e-aa1e-034ef85a74ea',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.440046',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'GCMD Keyword Forum Page',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 11,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://forum.earthdata.nasa.gov/app.php/tag/GCMD%2BKeywords',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466391',
#     'description': 'NOAA Central Library: iii, 47 p.; ill., maps; 30 cm',
#     'format': '',
#     'hash': '',
#     'id': '4dd6e42c-541f-4f2a-9bd8-6b39d418c5e6',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.440162',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'Related publication(s)',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 12,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://discover.library.noaa.gov/permalink/01NOAA_INST/1qbesct/alma991000267699707381',
#     'url_type': None},
#    {'cache_last_updated': None,
#     'cache_url': None,
#     'created': '2023-11-01T22:02:00.466392',
#     'description': 'Institution web page',
#     'format': '',
#     'hash': '',
#     'id': 'b938ad47-5643-49bb-9e2e-ddc0846470b8',
#     'last_modified': None,
#     'metadata_modified': '2023-11-01T22:02:00.440298',
#     'mimetype': None,
#     'mimetype_inner': None,
#     'name': 'NOAA Central Library website',
#     'package_id': '2febdedb-aaac-472d-b906-6acd30a30abc',
#     'position': 13,
#     'resource_locator_function': 'information',
#     'resource_locator_protocol': 'HTTPS',
#     'resource_type': None,
#     'size': None,
#     'state': 'active',
#     'url': 'https://library.noaa.gov/',
#     'url_type': None}],
#   'tags': [{'display_name': 'oceanography',
#     'id': '870d5b55-1fe2-4990-848f-08ad8e71b310',
#     'name': 'oceanography',
#     'state': 'active',
#     'vocabulary_id': None}],
#   'groups': [],
#   'relationships_as_subject': [],
#   'relationships_as_object': []}]
